Visualize a cozy log cabin tucked away in a snowy forest, with smoke rising from the chimney.
Depict a tranquil village scene with thatched-roof cottages and grazing sheep.
Create an image of a colorful carnival with rides, games, and cotton candy.
Illustrate the energy of a crowded nightclub with pulsating lights and thumping music.
Show a serene countryside scene with rolling hills and grazing horses.
Render an image of a bustling farmers' market with vendors selling fresh produce and artisanal goods.
Depict a peaceful river winding through a lush green valley, with birds soaring overhead.
Paint a magical underwater kingdom with mermaids, seahorses, and vibrant coral reefs.
Visualize a cozy winter cabin with a roaring fireplace and snow falling outside.
Draw an idyllic island paradise with palm trees, white sand beaches, and turquoise waters.
Capture the beauty of a field of lavender in full bloom, with bees buzzing among the flowers.
Create an image of a tranquil Japanese garden with manicured bonsai trees and a serene koi pond.
Illustrate the excitement of a bustling street market with vendors selling exotic spices and handmade crafts.
Show a serene alpine meadow with wildflowers blooming and snow-capped peaks in the distance.
Depict a majestic sunrise over a misty lake, with birdsong filling the air.
Paint a tranquil forest scene with shafts of golden sunlight filtering through the trees.
Visualize a bustling harbor with fishing boats unloading their catch and seagulls circling overhead.
Render an image of a quaint seaside town with colorful cottages and a sandy beach.
Depict a serene vineyard at sunset, with rows of grapevines stretching to the horizon.
Create an image of a traditional Japanese ryokan with paper lanterns and sliding shoji doors.
Illustrate the energy of a busy city street with cars honking and pedestrians bustling by.
"""

# %%
text_to_image_prompts_list = text_to_image_prompts.replace("\"", "").split("\n")[1:-1]

# %%
TtI = set(text_to_image_prompts_list)

# %%
text_to_video_prompts = """
Describe a journey through a mystical forest with towering trees and shimmering streams.
Depict the hustle and bustle of a busy city street during rush hour.
Create a video montage showcasing the beauty of different seasons changing in nature.
Show the process of creating a piece of art from start to finish, from the initial sketch to the final masterpiece.
Visualize a day in the life of a bustling market, with vendors selling their goods and customers browsing.
Capture the essence of a relaxing day at the beach, with waves crashing and seagulls soaring overhead.
Illustrate the excitement of a thrilling roller coaster ride at an amusement park.
Create a time-lapse video of a flower blooming from a bud to full bloom.
Show the journey of a package being delivered from the warehouse to the recipient's doorstep.
Depict the process of cooking a delicious meal, from chopping ingredients to serving the finished dish.
Visualize the transformation of a caterpillar into a butterfly.
Capture the beauty of a sunset over a tranquil lake, with the colors reflecting on the water.
Create a video montage of people from diverse cultures and backgrounds coming together in unity.
Illustrate the excitement of a concert, with crowds cheering and music filling the air.
Show a day in the life of a busy city from dawn till dusk, with traffic, pedestrians, and city lights.
Depict the process of a seed growing into a tall, strong tree over the course of many years.
Visualize the journey of a paper plane as it soars through the sky and lands in different locations.
Create a time-lapse video of a city skyline as it changes from day to night.
Show the process of a book being written, edited, and published.
Illustrate the journey of a raindrop as it falls from the sky, joins a river, and eventually reaches the ocean.
Capture the excitement of a sports game, with players making impressive plays and fans cheering from the stands.
Depict the process of a city being built from an empty plot of land to a bustling metropolis.
Visualize the life cycle of a butterfly, from egg to caterpillar to chrysalis to adult butterfly.
Create a video montage showcasing the beauty of different landscapes around the world, from mountains to deserts to forests.
Show the process of a flower garden being planted, growing, and blooming in vibrant colors.
Create a video montage of a day in the life of a busy farm, with farmers tending to crops and animals from sunrise to sunset.
Show the process of a city street being transformed into a lively street performance venue, with musicians, dancers, and artists entertaining passersby.
Capture the beauty of a rainbow stretching across the sky after a storm, with vibrant colors arching from horizon to horizon.
Illustrate the journey of a lost pet as it searches for its way home, encountering obstacles and making new friends along the way.
Depict the excitement of a spacewalk, with astronauts floating outside their spacecraft and conducting repairs or experiments.
Visualize the process of a city street being transformed into a peaceful oasis, with green spaces, fountains, and benches for relaxation.
Create a time-lapse video of a city skyline as it evolves over centuries, from a small settlement to a bustling metropolis.
Show the journey of a message in a bottle as it drifts across the ocean, eventually washing ashore on a distant beach.
Illustrate the process of a glacier carving out a valley, with ice slowly flowing downhill and reshaping the landscape.
Depict the excitement of a rocket launch, with flames and smoke billowing as the spacecraft lifts off into space.
Visualize the journey of a group of friends as they embark on a camping trip, with campfires, hiking, and stargazing under the night sky.
Create a video montage of a day in the life of a bustling factory, with machines humming and workers bustling to meet production deadlines.
Capture the beauty of a solar eclipse, with the moon passing between the sun and the earth and casting a shadow across the landscape.
Illustrate the journey of a lost toy as it travels through different environments, from city streets to parks to beaches.
Depict the excitement of a flash mob, with dancers suddenly appearing in a public space and performing a choreographed routine.
Visualize the process of a city street being transformed into a vibrant parade route, with floats, balloons, and marching bands.
Create a time-lapse video of a garden as it attracts and supports a variety of pollinators, from bees to butterflies to hummingbirds.
Show the journey of a group of friends as they embark on a road trip, with laughter, adventure, and memories made along the way.
Capture the beauty of a coral reef teeming with life, with colorful fish darting among the coral formations.
Illustrate the journey of a monarch butterfly as it migrates thousands of miles to its wintering grounds in Mexico.
Depict the excitement of a music festival, with multiple stages hosting performances by a variety of artists and bands.
Visualize the process of a city street being transformed into a bustling food market, with vendors selling fresh produce, meats, and spices.
Create a time-lapse video of a forest as it recovers from a wildfire, with new growth sprouting from the charred landscape.
Show the journey of a piece of trash as it travels from a city street to a landfill or recycling center.
Illustrate the process of a skyscraper being constructed, from the excavation of the foundation to the placement of the final steel beam.
Depict the excitement of a flash flood, with water rushing through city streets and people evacuating to safety.
Visualize the journey of a comet as it streaks across the night sky, leaving a trail of glowing gas and dust in its wake.
Create a video montage of a day in the life of a busy farm, with farmers tending to crops and animals from sunrise to sunset.
Capture the beauty of a rainbow stretching across the sky after a storm, with vibrant colors arching from horizon to horizon.
Illustrate the journey of a lost pet as it searches for its way home, encountering obstacles and making new friends along the way.
Depict the excitement of a spacewalk, with astronauts floating outside their spacecraft and conducting repairs or experiments.
Visualize the process of a city street being transformed into a peaceful oasis, with green spaces, fountains, and benches for relaxation.
Create a time-lapse video of a city skyline as it evolves over centuries, from a small settlement to a bustling metropolis.
"Create a video illustrating the concept of artificial intelligence."
"Generate a video presentation on the impact of renewable energy sources."
"Produce a visual explanation of the water cycle."
"Craft a video tutorial on effective time management techniques."
"Illustrate the process of photosynthesis through animation."
"Create an educational video on the history of space exploration."
"Generate a video advertisement for a sustainable fashion brand."
"Produce a video showcasing the benefits of meditation for mental health."
"Craft a visual guide to understanding the principles of physics."
"Illustrate the life cycle of a butterfly through animation."
"Create a video essay on the importance of biodiversity conservation."
"Generate a virtual tour of famous landmarks around the world."
"Produce a video presentation on the future of transportation."
"Craft an animated story about overcoming obstacles and achieving success."
"Illustrate the effects of climate change on ecosystems."
"Create a video guide to mastering a musical instrument."
"Generate a visual explanation of the human digestive system."
"Produce a video tutorial on creating a healthy meal plan."
"Craft a promotional video for a new mobile app."
"Illustrate the process of building a sustainable home."
"Create an animated infographic on global population trends."
"Generate a video presentation on the importance of mental health awareness."
"Produce a video essay exploring the concept of identity."
"Craft a visual guide to understanding cryptocurrency."
"Illustrate the journey of a product from manufacturing to delivery."
"Create a video tutorial on basic coding principles."
"Generate a virtual reality experience of an ancient civilization."
"Produce a video advertisement for a wildlife conservation organization."
"Craft an animated story about friendship and teamwork."
"Illustrate the process of democratic elections through animation."
"Create a video guide to starting a small business."
"Generate a visual explanation of the theory of relativity."
"Produce a video presentation on the psychology of motivation."
"Craft a promotional video for an eco-friendly product."
"Illustrate the impact of social media on society."
"Create an animated infographic on the benefits of exercise."
"Generate a video tutorial on DIY home improvement projects."
"Produce a virtual tour of a futuristic city."
"Craft a video essay on the ethics of artificial intelligence."
"Illustrate the process of evolution through animation."
"Create a video guide to surviving in the wilderness."
"Generate a visual explanation of the principles of economics."
"Produce a video presentation on the history of cinema."
"Craft a promotional video for a charitable organization."
"Illustrate the journey of a drop of water through the water cycle."
"Create an animated story about environmental conservation."
"Generate a video tutorial on mastering a new language."
"Produce a virtual reality experience of a historical event."
"Craft a video advertisement for a healthy lifestyle app."
"Illustrate the process of cellular respiration through animation."
"Create a video guide to effective communication skills."
"Generate a visual explanation of the human reproductive system."
"Produce a video presentation on the future of artificial intelligence."
"Craft a video essay on the impact of social media on mental health."
"Illustrate the life cycle of a star through animation."
"Create a promotional video for a sustainable agriculture initiative."
"Generate a virtual tour of an underwater coral reef."
"Produce a video tutorial on digital photography techniques."
"Craft an animated story about the importance of education."
"Illustrate the process of globalization through animation."
"Create a video guide to financial planning and budgeting."
"Generate a visual explanation of the theory of evolution."
"Produce a video presentation on the art of storytelling."
"Craft a promotional video for a renewable energy company."
"Illustrate the impact of deforestation on climate change."
"Create an animated infographic on the benefits of mindfulness."
"Generate a video tutorial on basic first aid techniques."
"Produce a virtual tour of a famous museum."
"Craft a video advertisement for a sustainable transportation solution."
"Illustrate the process of mitosis through animation."
"Create a video guide to effective study habits."
"Generate a visual explanation of the principles of democracy."
"Produce a video presentation on the history of photography."
"Craft a video essay on the future of renewable energy."
"Illustrate the life cycle of a plant through animation."
"Create a promotional video for a wildlife conservation project."
"Generate a virtual tour of a space station."
"Produce a video tutorial on DIY natural skincare recipes."
"Craft an animated story about resilience in the face of adversity."
"Illustrate the process of continental drift through animation."
"Create a video guide to effective conflict resolution."
"Generate a visual explanation of the principles of psychology."
"Produce a video presentation on the art of public speaking."
"Craft a promotional video for a sustainable fashion line."
"Illustrate the impact of pollution on marine life."
"Create an animated infographic on the benefits of volunteering."
"Generate a video tutorial on home gardening techniques."
"Produce a virtual tour of a prehistoric archaeological site."
"Craft a video advertisement for a clean energy initiative."
"Illustrate the process of meiosis through animation."
"Create a video guide to effective time management for students."
"Generate a visual explanation of the principles of sociology."
"Produce a video presentation on the history of animation."
"Craft a video essay on the future of space exploration."
"Illustrate the life cycle of a frog through animation."
"Create a promotional video for an environmental conservation charity."
"Generate a virtual tour of a futuristic sustainable city."
"Produce a video tutorial on DIY home decor ideas."
"Craft an animated story about the importance of empathy."
"Illustrate the process of plate tectonics through animation."
"Create a video guide to effective negotiation skills."
"Generate a visual explanation of the principles of marketing."
"Produce a video presentation on the history of literature."
"Craft a promotional video for a social justice campaign."
"Illustrate the impact of urbanization on wildlife habitats."
"Create an animated infographic on the benefits of laughter."
"Generate a video tutorial on basic car maintenance."
"Produce a virtual tour of an ancient archaeological site."
"Craft a video advertisement for an eco-friendly lifestyle brand."
"Illustrate the process of gene expression through animation."
"Create a video guide to effective leadership skills."
"Generate a visual explanation of the principles of ethics."
"Produce a video presentation on the history of music."
"Craft a video essay on the future of artificial intelligence in healthcare."
"Illustrate the life cycle of a bird through animation."
"Create a promotional video for a reforestation initiative."
"Generate a virtual tour of a sustainable eco-village."
"Produce a video tutorial on DIY natural cleaning products."
"Craft an animated story about cultural diversity."
"Illustrate the process of ocean currents through animation."
"Create a video guide to effective problem-solving techniques."
"Generate a visual explanation of the principles of nutrition."
"Produce a video presentation on the history of philosophy."
"Craft a promotional video for a mental health awareness campaign."
"Illustrate the impact of overfishing on marine ecosystems."
"Create an animated infographic on the benefits of kindness."
"Generate a video tutorial on basic self-defense techniques."
"Produce a virtual tour of a famous ancient civilization."
"Craft a video advertisement for a sustainable tourism initiative."
"Illustrate the process of cellular division through animation."
"Create a video guide to effective decision-making skills."
"Generate a visual explanation of the principles of negotiation."
"Produce a video presentation on the history of architecture."
"Craft a video essay on the future of renewable energy in transportation."
"Illustrate the life cycle of a tree through animation."
"Create a promotional video for a wildlife preservation project."
"Generate a virtual tour of a futuristic sustainable community."
"Produce a video tutorial on DIY natural beauty products."
"Craft an animated story about the power of resilience."
"Illustrate the process of weathering and erosion through animation."
"Create a video guide to effective communication in relationships."
"Generate a visual explanation of the principles of finance."
"Produce a video presentation on the history of cinema technology."
"Craft a promotional video for a renewable energy research institute."
"Illustrate the impact of plastic pollution on ocean life."
"Create an animated infographic on the benefits of generosity."
"Generate a video tutorial on basic home repair skills."
"Produce a virtual tour of a famous historical battlefield."
"Craft a video advertisement for a sustainable agriculture project."
"Illustrate the process of protein synthesis through animation."
"Create a video guide to effective conflict resolution in the workplace."
"Generate a visual explanation of the principles of business ethics."
"Produce a video presentation on the history of fashion."
"Craft a video essay on the future of artificial intelligence in education."
"Illustrate the life cycle of a bee through animation."
"Create a promotional video for a clean water initiative."
"Generate a virtual tour of a sustainable urban farming community."
"Produce a video tutorial on DIY natural hair care."
"Craft an animated story about the importance of perseverance."
"Illustrate the process of sedimentary rock formation through animation."
"Create a video guide to effective stress management techniques."
"Generate a visual explanation of the principles of leadership."
"Produce a video presentation on the history of photography technology."
"Craft a promotional video for a mental health advocacy organization."
"Illustrate the impact of climate change on polar ice caps."
"Create an animated infographic on the benefits of compassion."
"Generate a video tutorial on basic gardening techniques for beginners."
"Produce a virtual tour of a famous archaeological discovery site."
"Craft a video advertisement for a sustainable transportation project."
"Illustrate the process of natural selection through animation."
"Create a video guide to effective time management in the workplace."
"Generate a visual explanation of the principles of environmental ethics."
"Produce a video presentation on the history of graphic design."
"Craft a video essay on the future of renewable energy in urban planning."
"Illustrate the life cycle of a salmon through animation."
"Create a promotional video for a wildlife conservation initiative."
"Generate a virtual tour of a sustainable eco-friendly resort."
"Produce a video tutorial on DIY natural skincare remedies."
"Craft an animated story about the importance of community."
"Illustrate the process of metamorphosis through animation."
"Create a video guide to effective conflict resolution in friendships."
"Generate a visual explanation of the principles of sustainable development."
"Produce a video presentation on the history of computer technology."
"Craft a promotional video for a renewable energy startup."
"Illustrate the impact of ocean acidification on marine ecosystems."
"Create an animated infographic on the benefits of forgiveness."
"Generate a video tutorial on basic survival skills."
"Produce a virtual tour of a famous ancient religious site."
"Craft a video advertisement for a sustainable architecture project."
"Illustrate the process of evolution by natural selection through animation."
"Create a video guide to effective parenting techniques."
"Generate a visual explanation of the principles of organizational behavior."
"Produce a video presentation on the history of space technology."
"Craft a video essay on the future of artificial intelligence in entertainment."
"Illustrate the life cycle of a turtle through animation."
"Create a promotional video for a renewable energy awareness campaign."
"Generate a virtual tour of a sustainable green building."
"Produce a video tutorial on DIY natural cleaning solutions."
"Craft an animated story about the power of empathy."
"Illustrate the process of erosion and deposition through animation."
"Create a video guide to effective conflict resolution in romantic relationships."
"Generate a visual explanation of the principles of corporate social responsibility."
"Produce a video presentation on the history of virtual reality technology."
"Craft a promotional video for a mental health support network."
"Illustrate the impact of deforestation on indigenous communities."
"Create an animated infographic on the benefits of gratitude."
"Generate a video tutorial on basic wilderness survival skills."
"Produce a virtual tour of a famous ancient architectural wonder."
"Craft a video advertisement for a sustainable energy infrastructure project."
"Illustrate the process of continental drift and plate tectonics through animation."
"Create a video guide to effective communication in multicultural environments."
"Generate a visual explanation of the principles of cultural diversity."
"Produce a video presentation on the history of video game technology."
"Craft a video essay on the future of artificial intelligence in warfare."
"Illustrate the life cycle of a butterfly through animation."
"Create a promotional video for a renewable energy policy initiative."
"Generate a virtual tour of a sustainable eco-friendly city."
"Produce a video tutorial on DIY natural beauty remedies."
"Craft an animated story about the importance of compassion."
"Illustrate the process of volcanic eruption through animation."
"Create a video guide to effective conflict resolution in the family."
"Generate a visual explanation of the principles of cultural relativism."
"Produce a video presentation on the history of film technology."
"Craft a promotional video for a mental health awareness campaign."
"Illustrate the impact of climate change on indigenous cultures."
"Create an animated infographic on the benefits of mindfulness."
"Generate a video tutorial on basic outdoor survival skills."
"Produce a virtual tour of a famous ancient archaeological site."
"Craft a video advertisement for a sustainable agriculture project."
"Illustrate the process of erosion and weathering through animation."
"Create a video guide to effective communication in the workplace."
"Generate a visual explanation of the principles of cultural competency."
"Produce a video presentation on the history of music technology."
"Craft a video essay on the future of artificial intelligence in medicine."
"Illustrate the life cycle of a flower through animation."
"Create a promotional video for a renewable energy advocacy group."
"Generate a virtual tour of a sustainable eco-village."
"Produce a video tutorial on DIY natural home remedies."
"Craft an animated story about the importance of empathy."
"Illustrate the process of glacier formation and movement through animation."
"Create a video guide to effective conflict resolution in friendships."
"Generate a visual explanation of the principles of environmental justice."
"Produce a video presentation on the history of computer science."
"Craft a promotional video for a mental health awareness initiative."
"Illustrate the impact of deforestation on biodiversity."
"Create an animated infographic on the benefits of mindfulness meditation."
"Generate a video tutorial on basic survival skills for outdoor adventures."
"Produce a virtual tour of a famous ancient historical site."
"Craft a video advertisement for a sustainable transportation project."
"Illustrate the process of continental drift and plate tectonics through animation."
"Create a video guide to effective communication in multicultural teams."
"Generate a visual explanation of the principles of cultural diversity."
"Produce a video presentation on the history of video game development."
"Craft a video essay on the future of artificial intelligence in warfare."
"Illustrate the life cycle of a butterfly through animation."
"Create a promotional video for a renewable energy policy initiative."
"Generate a virtual tour of a sustainable eco-friendly city."
"Produce a video tutorial on DIY natural beauty remedies."
"Craft an animated story about the importance of compassion."
"Illustrate the process of volcanic eruption through animation."
"Create a video guide to effective conflict resolution in the family."
"Generate a visual explanation of the principles of cultural relativism."
"Produce a video presentation on the history of film technology."
"Craft a promotional video for a mental health awareness campaign."
"Illustrate the impact of climate change on indigenous cultures."
"Create an animated infographic on the benefits of mindfulness."
"Generate a video tutorial on basic outdoor survival skills."
"Produce a virtual tour of a famous ancient archaeological site."
"Craft a video advertisement for a sustainable agriculture project."
"Illustrate the process of erosion and weathering through animation."
"Create a video guide to effective communication in the workplace."
"Generate a visual explanation of the principles of cultural competency."
"Produce a video presentation on the history of music technology."
"Craft a video essay on the future of artificial intelligence in medicine."
"Illustrate the life cycle of a flower through animation."
"Create a promotional video for a renewable energy advocacy group."
"Generate a virtual tour of a sustainable eco-village."
"Produce a video tutorial on DIY natural home remedies."
"Craft an animated story about the importance of empathy."
"Illustrate the process of glacier formation and movement through animation."
"Create a video guide to effective conflict resolution in friendships."
"Generate a visual explanation of the principles of environmental justice."
"Produce a video presentation on the history of computer science."
"Craft a promotional video for a mental health awareness initiative."
"Illustrate the impact of deforestation on biodiversity."
"Create an animated infographic on the benefits of mindfulness meditation."
"Generate a video tutorial on basic survival skills for outdoor adventures."
"Produce a virtual tour of a famous ancient historical site."
"Craft a video advertisement for a sustainable transportation project."
"Illustrate the process of continental drift and plate tectonics through animation."
"Create a video guide to effective communication in multicultural teams."
"Generate a visual explanation of the principles of cultural diversity."
"Produce a video presentation on the history of video game development."
"Craft a video essay on the future of artificial intelligence in warfare."
"Illustrate the life cycle of a butterfly through animation."
"Create a promotional video for a renewable energy policy initiative."
"Generate a virtual tour of a sustainable eco-friendly city."
"Produce a video tutorial on DIY natural beauty remedies."
"Craft an animated story about the importance of compassion."
"Illustrate the process of volcanic eruption through animation."
"Create a video guide to effective conflict resolution in the family."
"Generate a visual explanation of the principles of cultural relativism."
"Produce a video presentation on the history of film technology."
"Craft a promotional video for a mental health awareness campaign."
"Illustrate the impact of climate change on indigenous cultures."
"Create an animated infographic on the benefits of mindfulness."
"Generate a video tutorial on basic outdoor survival skills."
"Produce a virtual tour of a famous ancient archaeological site."
"Craft a video advertisement for a sustainable agriculture project."
"Illustrate the process of erosion and weathering through animation."
"Create a video guide to effective communication in the workplace."
"Generate a visual explanation of the principles of cultural competency."
"Produce a video presentation on the history of music technology."
"Craft a video essay on the future of artificial intelligence in medicine."
"Illustrate the life cycle of a flower through animation."
"Create a promotional video for a renewable energy advocacy group."
"Generate a virtual tour of a sustainable eco-village."
"Produce a video tutorial on DIY natural home remedies."
"Craft an animated story about the importance of empathy."
"Illustrate the process of glacier formation and movement through animation."
"Create a video guide to effective conflict resolution in friendships."
"Generate a visual explanation of the principles of environmental justice."
"Produce a video presentation on the history of computer science."
"Craft a promotional video for a mental health awareness initiative."
"Illustrate the impact of deforestation on biodiversity."
"Create an animated infographic on the benefits of mindfulness meditation."
"Generate a video tutorial on basic survival skills for outdoor adventures."
"Produce a virtual tour of a famous ancient historical site."
"Craft a video advertisement for a sustainable transportation project."
"Illustrate the process of continental drift and plate tectonics through animation."
"Create a video guide to effective communication in multicultural teams."
"Generate a visual explanation of the principles of cultural diversity."
"Produce a video presentation on the history of video game development."
"Craft a video essay on the future of artificial intelligence in warfare."
"Illustrate the life cycle of a butterfly through animation."
"Create a promotional video for a renewable energy policy initiative."
"Generate a virtual tour of a sustainable eco-friendly city."
"Produce a video tutorial on DIY natural beauty remedies."
"Craft an animated story about the importance of compassion."
"Illustrate the process of volcanic eruption through animation."
"Create a video guide to effective conflict resolution in the family."
"Generate a visual explanation of the principles of cultural relativism."
"Produce a video presentation on the history of film technology."
"Craft a promotional video for a mental health awareness campaign."
"Illustrate the impact of climate change on indigenous cultures."
"Create an animated infographic on the benefits of mindfulness."
"Generate a video tutorial on basic outdoor survival skills."
"Produce a virtual tour of a famous ancient archaeological site."
"Craft a video advertisement for a sustainable agriculture project."
"Illustrate the process of erosion and weathering through animation."
"Create a video guide to effective communication in the workplace."
"Generate a visual explanation of the principles of cultural competency."
"Produce a video presentation on the history of music technology."
"Craft a video essay on the future of artificial intelligence in medicine."
"Illustrate the life cycle of a flower through animation."
"Create a promotional video for a renewable energy advocacy group."
"Generate a virtual tour of a sustainable eco-village."
"Produce a video tutorial on DIY natural home remedies."
"Craft an animated story about the importance of empathy."
"Illustrate the process of glacier formation and movement through animation."
"Create a video guide to effective conflict resolution in friendships."
"Generate a visual explanation of the principles of environmental justice."
"Produce a video presentation on the history of computer science."
"Craft a promotional video for a mental health awareness initiative."
"Illustrate the impact of deforestation on biodiversity."
"Create an animated infographic on the benefits of mindfulness meditation."
"Generate a video tutorial on basic survival skills for outdoor adventures."
"Produce a virtual tour of a famous ancient historical site."
"Craft a video advertisement for a sustainable transportation project."
"Illustrate the process of continental drift and plate tectonics through animation."
"Create a video guide to effective communication in multicultural teams."
"Generate a visual explanation of the principles of cultural diversity."
"Produce a video presentation on the history of video game development."
"Craft a video essay on the future of artificial intelligence in warfare."
"Illustrate the life cycle of a butterfly through animation."
"Create a promotional video for a renewable energy policy initiative."
"Generate a virtual tour of a sustainable eco-friendly city."
"Produce a video tutorial on DIY natural beauty remedies."
"Craft an animated story about the importance of compassion."
"Illustrate the process of volcanic eruption through animation."
"Create a video guide to effective conflict resolution in the family."
"Generate a visual explanation of the principles of cultural relativism."
"Produce a video presentation on the history of film technology."
"Craft a promotional video for a mental health awareness campaign."
"Illustrate the impact of climate change on indigenous cultures."
"Create an animated infographic on the benefits of mindfulness."
"Generate a video tutorial on basic outdoor survival skills."
"Produce a virtual tour of a famous ancient archaeological site."
"Craft a video advertisement for a sustainable agriculture project."
"Illustrate the process of erosion and weathering through animation."
"Create a video guide to effective communication in the workplace."
"Generate a visual explanation of the principles of cultural competency."
"Produce a video presentation on the history of music technology."
"Craft a video essay on the future of artificial intelligence in medicine."
"Illustrate the life cycle of a flower through animation."
"Create a promotional video for a renewable energy advocacy group."
"Generate a virtual tour of a sustainable eco-village."
"Produce a video tutorial on DIY natural home remedies."
"Craft an animated story about the importance of empathy."
"Illustrate the process of glacier formation and movement through animation."
"""

# %%
text_to_video_prompts_list = text_to_video_prompts.replace("\"", "").split("\n")[1:-1]

# %%
TtV = set(text_to_video_prompts_list)

# %%
dataset = []
for prompt in TtI:
    dataset.append({"prompt":prompt, "video":False})
for prompt in TtV:
    dataset.append({"prompt":prompt, "video":True})

# %%
len(dataset)
# Out:
# 527

# %%
import random
random.shuffle(dataset)

# %%
dataset
# Out:
# [{'prompt': 'Capture the serenity of a foggy morning in the countryside.',
#   'video': False},
#  {'prompt': 'Illustrate the life cycle of a tree through animation.',
#   'video': True},
#  {'prompt': 'Generate a visual explanation of the principles of cultural relativism.',
#   'video': True},
#  {'prompt': 'Illustrate the hustle and bustle of a busy airport terminal.',
#   'video': False},
#  {'prompt': 'Generate a virtual tour of a sustainable green building.',
#   'video': True},
#  {'prompt': 'Illustrate the life cycle of a bird through animation.',
#   'video': True},
#  {'prompt': 'Create a time-lapse video of a city skyline as it evolves over centuries, from a small settlement to a bustling metropolis.',
#   'video': True},
#  {'prompt': 'Visualize the process of a painting being created, from the blank canvas to the finished artwork.',
#   'video': True},
#  {'prompt': 'Illustrate the journey of a drop of water through the water cycle.',
#   'video': True},
# ...

# %%
import httpx
import asyncio
import pandas as pd
from IPython.display import clear_output

async def send_request_without_waiting(request_body:dict):
    async with httpx.AsyncClient() as client:
        # Отправить запрос без ожидания ответа
        print("request send")
        response = await client.post('http://0.0.0.0:8090/', json=request_body, timeout=60*3)
        response_data = response.json()
        status_code = response.status_code
        return status_code, response_data

# %%
import asyncio
import random
import pandas as pd
import time
from IPython.display import clear_output

async def main(errors):
    columns = ['Episode', 'Video', 'Status_Code', 'TimeSleep', 'ResponseTime', 'ServerLoads', 'MRT', 'QL',]
    df = pd.DataFrame(columns=columns)
    for idx, request_body in enumerate(dataset):
        try:
            start_time = time.time()
            task = asyncio.create_task(send_request_without_waiting(request_body))
            status_code, response_data = await task
            response_time = time.time() - start_time
            sl = response_data.get("server_loads")
            mrt = response_data.get("mrt")
            ql = response_data.get("queue_len")
            time_sleep = random.randint(0, 3)
            row = {
                'Episode': idx,
                'Video': request_body['video'],
                'Status_Code': status_code,
                'TimeSleep': time_sleep,
                'ResponseTime': response_time,
                'ServerLoads': sl,
                'MRT': mrt,
                'QL': ql,
                'CountErrors': len(errors),
            }
            df.loc[len(df)] = row

            if (idx + 1) % 10 == 0:
                clear_output()
                print(df.to_string(index=False))

            await asyncio.sleep(time_sleep)

        except httpx.ReadTimeout as e:
            errors.append(idx)
        except httpx.ConnectError as e:
            print("server was destroyed")
            return df
        except httpx.RemoteProtocolError as e:
            print("server was destroyed")
            return df

    return df

# %%
errors = []
df = await main(errors)
# Out:
# ---------------------------------------------------------------------------
# RemoteProtocolError                       Traceback (most recent call last)
# File /usr/local/lib/python3.10/dist-packages/httpx/_transports/default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File /usr/local/lib/python3.10/dist-packages/httpx/_transports/default.py:373, in AsyncHTTPTransport.handle_async_request(self, request)
#     372 with map_httpcore_exceptions():
# --> 373     resp = await self._pool.handle_async_request(req)
#     375 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File /usr/local/lib/python3.10/dist-packages/httpcore/_async/connection_pool.py:216, in AsyncConnectionPool.handle_async_request(self, request)
#     215     await self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
# ...

# %%
print(df)
# Out:
#     Episode  Video  Status_Code  TimeSleep  ResponseTime      ServerLoads  \
# 0         0  False          200          2      9.565716  [0.0, 0.0, 0.0]
# 1         1   True          200          0      8.257664  [0.0, 0.0, 0.0]
# 2         2   True          200          2      6.105173  [0.0, 0.0, 0.0]
# 3         3  False          200          1      9.684979  [0.0, 0.0, 0.0]
# 4         4   True          200          2      9.470976  [0.0, 0.0, 0.0]
# 5         5   True          200          2      6.848288  [0.0, 0.0, 0.0]
# 6         6   True          200          0      6.420647  [0.0, 0.0, 0.0]
# 7         7   True          200          3      9.965653  [0.0, 0.0, 0.0]
# 8         8   True          200          2      6.336872  [0.0, 0.0, 0.0]
# 9         9  False          200          0      6.177477  [0.0, 0.0, 0.0]
# 10       10   True          200          1     64.729258  [0.0, 0.0, 0.0]
# 11       11  False          200          2      5.382616  [0.0, 0.0, 0.0]
# ...

# %%
httpx.get('http://0.0.0.0:8083/load').json()['GPUload']
# Out:
# 0.5

# %%
import pandas as pd
import matplotlib.pyplot as plt
PATH = "../LBServer/models/"
datas = {
    1: "first/server_eff_1.25_time_bon_1.3_reward_2.5_fine_-5_episodes_12.csv",
    2: "second/server_eff_1.5_time_bon_1.75_reward_2.5_fine_-10_episodes_12.csv",
    3: "third/server_eff_1.5_time_bon_1.25_reward_1.5_fine_-15_episodes_8.csv"
}
linestyles = ['solid','dashed','dashdot']

plt.figure(figsize=(12, 4))

# Проходим по словарю и обрабатываем каждый файл
for model_number, file_name in datas.items():
    # Загрузка данных из файла .csv в DataFrame
    df = pd.read_csv(PATH+file_name)
    
    # Подсчет префиксной суммы по столбцу 'value'
    df['prefix_sum'] = df['reward'][:800].cumsum()
    
    # Построение графика префиксных сумм
    plt.plot(df['prefix_sum'], label=f'Model {model_number}', linestyle=linestyles[model_number-1], linewidth=3)


# Настройки графика
plt.title('Prefix Sums of Rewards')
plt.xlabel('Request')
plt.ylabel('Prefix Sum')
plt.legend()
plt.grid(True)

# Отображение графика
plt.show()

# %%
linestyles = ['solid','dashed','dashdot', 'dotted']

plt.figure(figsize=(12, 4))

# Проходим по словарю и обрабатываем каждый файл
for model_number, file_name in datas.items():
    # Загрузка данных из файла .csv в DataFrame
    df = pd.read_csv(PATH+file_name)
    plt.plot(df['loss'][:800], label=f'Model {model_number}', linestyle=linestyles[model_number-1], linewidth=2)


# Настройки графика
plt.title('Prefix Sums of Rewards')
plt.xlabel('Request')
plt.ylabel('Prefix Sum')
plt.legend()
plt.grid(True)

# Отображение графика
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Путь к папке с файлами
PATH = "../LBServer/models/"

# Словарь с данными
datas = {
    1: "first/server_eff_1.25_time_bon_1.3_reward_2.5_fine_-5_episodes_12.csv",
    2: "second/server_eff_1.5_time_bon_1.75_reward_2.5_fine_-10_episodes_12.csv",
    3: "third/server_eff_1.5_time_bon_1.25_reward_1.5_fine_-15_episodes_8.csv"
}

linestyles = ['solid', 'dashed', 'dashdot']

# Создание фигуры и двух подграфиков (осей)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Проходим по словарю и обрабатываем каждый файл для первого подграфика
for model_number, file_name in datas.items():
    # Загрузка данных из файла .csv в DataFrame
    df = pd.read_csv(PATH + file_name)
    
    # Подсчет префиксной суммы по столбцу 'reward'
    df['prefix_sum'] = df['reward'][:800].cumsum()
    
    # Построение графика префиксных сумм на первом подграфике
    ax1.plot(df['prefix_sum'], label=f'Model {model_number}', linestyle=linestyles[model_number-1], linewidth=3)

# Настройки первого подграфика
ax1.set_title('Prefix Sums of Rewards')
ax1.set_xlabel('Request')
ax1.set_ylabel('Prefix Sum')
ax1.legend()
ax1.grid(True)

# Проходим по словарю и обрабатываем каждый файл для второго подграфика
for model_number, file_name in datas.items():
    # Загрузка данных из файла .csv в DataFrame
    df = pd.read_csv(PATH + file_name)
    
    # Построение графика потерь на втором подграфике
    ax2.plot(df['loss'][:800], label=f'Model {model_number}', linestyle=linestyles[model_number-1], linewidth=2)

# Настройки второго подграфика
ax2.set_title('Losses')
ax2.set_xlabel('Request')
ax2.set_ylabel('Loss')
ax2.legend()
ax2.grid(True)

# Отображение графиков
plt.tight_layout()
plt.show()

# %%
dfs = {
    "minmin":  "df_minmin_epoch_1.csv",
    "model 1": "df_model_1_epoch_2.csv",
    "model 2": "df_model_2_epoch_3.csv",
    "model 3": "df_model_3_epoch_1.csv",
}

linestyles = ['solid','dashed','dashdot', 'dotted']

plt.figure(figsize=(12, 4))
i=0
for line_title, file_name in dfs.items():
    df = pd.read_csv(file_name)['MRT']
    plt.plot(
        df,
        label=line_title,
        linewidth=3,
        linestyle=linestyles[i]
        )
    i+=1


# Настройки графика
plt.title('Prefix Sums of Rewards')
plt.xlabel('Request')
plt.ylabel('Prefix Sum')
plt.legend()
plt.grid(True)

# Отображение графика
plt.show()
